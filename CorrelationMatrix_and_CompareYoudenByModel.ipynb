# %%
# Import numpy, pandas and pyplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create variable "data" containing the data from the voice.csv file
data = pd.read_csv("voice.csv")

# Convert the label from text male/female to binary value of 1 or 0
data.label = [1 if each == "male" else 0 for each in  data.label]
# Show head of data to confirm that label value is changed
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000      1
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632      1
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512      1
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
#
# [5 rows x 21 columns]

# %%
# Set a dataframe with the data
df = pd.DataFrame(data)
# Set up a correlational matrix
corr = df.corr()
# Output correlational matrix with coolwarm colour-styling
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col1 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col2 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col3 {
#             background-color:  #c53334;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col4 {
#             background-color:  #ec7f63;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col5 {
#             background-color:  #6384eb;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col6 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col7 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col8 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col10 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col11 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col12 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col13 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col14 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col15 {
#             background-color:  #f7b093;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col16 {
#             background-color:  #cad8ef;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col17 {
#             background-color:  #f7b497;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col18 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col19 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow0_col20 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col0 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col2 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col3 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col4 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col5 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col6 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col7 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col8 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col9 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col11 {
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col12 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col13 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col14 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col15 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col16 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col17 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col18 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col19 {
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow1_col20 {
#             background-color:  #f7a688;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col0 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col1 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col3 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col4 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col5 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col6 {
#             background-color:  #6180e9;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col7 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col8 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col9 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col10 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col11 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col12 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col13 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col14 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col15 {
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col16 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_d11bb37a_986a_11ea_8742_e4a7a00c87eerow2_col17 {
#             background-color:  #f4c5ad;

# %%
x = ['KNeighbor', 'LinearSVC', 'DecisionTree', 'RandomForest']
y = [0.94002, 0.95594, 0.93232, 0.96656]

plt.bar(x, y, color=['yellow', 'orange', 'red', 'pink'])
plt.grid(True)
plt.xlabel('MODELS')
plt.ylabel('YOUDEN INDEX')
plt.legend()
plt.title('Model Comparison')
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Model Comparison')
