# %%
# Import numpy and pandas
import numpy as np
import pandas as pd
# Import operating specific functionality
import os
import seaborn as sn
import matplotlib.pyplot as plt

# %%
# Create variable "data" containing the data from the voice.csv file
data = pd.read_csv("voice.csv")

# %%
# Show the head of the data, confirming that the data is read and that we have all columns
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
# Convert the label from text male/female to binary value of 1 or 0
data.label = [1 if each == "male" else 0 for each in  data.label]
# Show head of data to confirm that label value is changed
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000      1
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632      1
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512      1
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
#
# [5 rows x 21 columns]

# %%
# Set variable "gender" to be the label column
gender = data.label
# Drop the label column from the data so that we now have features and labels separated
data.drop(["label"], axis = 1, inplace = True)

# %%
#Normalize the data to ensure that differing magnitude within features does not create a problem when running the model
data = (data-np.min(data))/(np.max(data)-np.min(data))

# Set variable "features" to be the normalized data
features = data

features.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  0.096419  0.473409  0.084125  0.060063  0.204956  0.254828  0.367853
# 1  0.125828  0.505075  0.116900  0.077635  0.215683  0.246961  0.644279
# 2  0.179222  0.675536  0.102873  0.034284  0.385912  0.457148  0.885255
# 3  0.528261  0.554611  0.587559  0.389906  0.715802  0.407358  0.031549
# 4  0.452195  0.627209  0.454272  0.317627  0.707515  0.474474  0.027742
#
#        kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0  0.208279  0.635798  0.564526  0.000000  0.096419  0.157706  0.030501
# 1  0.483766  0.630964  0.591578  0.000000  0.125828  0.287642  0.031140
# 2  0.782275  0.442738  0.548382  0.000000  0.179222  0.236945  0.030264
# 3  0.001613  0.923261  0.856457  0.299565  0.528261  0.183442  0.041287
# 4  0.001732  0.958736  0.926348  0.372362  0.452195  0.279190  0.036829
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# 0  0.981526  0.000000  0.006452  0.000000  0.000000  0.000000
# 1  0.834600  0.000407  0.006452  0.002144  0.002146  0.056449
# 2  0.954963  0.000060  0.006452  0.000357  0.000358  0.049885
# 3  0.834600  0.065659  0.006452  0.025375  0.025393  0.265043
# 4  0.929285  0.238994  0.006452  0.250536  0.250715  0.223380

# %%
# Import train_test_split function from scikit-learn
from sklearn.model_selection import train_test_split

# Split data into training set and testing set with a test size of 30% of the samples.
# The integer 42 is used for shuffling the data
x_train, x_test, y_train, y_test = train_test_split(features, gender, test_size = 0.2, random_state = 42)

# %%
import time
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier

F_Optimal = 0
best_youden = 0
youden_scores = []
cv_scores = []


for F in range(1,20):
    
    DTC = DecisionTreeClassifier(max_features=F)
    
    y_train_pred = cross_val_predict(DTC, x_train, y_train, cv = 5)
    
    scores= cross_val_score(DTC,x_train,y_train, cv= 5)
    
    print("Scores")
    print(scores)

    print("Confusion Matrix for F (max_features) of {}".format(F))
    print(confusion_matrix(y_train, y_train_pred))
    
    # Get the values for True Negatives,False Positives, Falses Negatives and True Positives
    tn, fp, fn, tp = confusion_matrix(y_train, y_train_pred).ravel()
    # Print the 4 values from above
    print("tn: {}, fp: {}, fn: {}, tp: {}".format(tn, fp, fn, tp))
    
    # Calculate sensitivity and Specificity
    sens = tp / (tp + fn)
    spec = tn / (fp + tn)
    
    # Calculate the Youdens Index and add it to the array of all youden indeces
    youden = sens - (1 - spec)
    youden_scores.append(youden)
    
    # Add the score for this cross validation to the array of scores
    cv_scores.append(scores)
                     
    print("Accuracy of score of F of {}: {:.4f}(+/- {:.4f})".format(F, scores.mean(), scores.std() * 2))
    print("Youdens Index for F of {}: {:.4f}\n ".format(F, youden))
            
    if best_youden < youden:
        best_youden = youden
        F_optimal = F

# Print the optimal F value and it's accuracy
print("The optimal F value is {} with a Youden Index of {:.4f}".format(F_optimal, best_youden))

#result changes every time we run, so we must conclude it is insignifiant in hyperparamter on this dataset
# Out:
# Scores
# [0.92110454 0.91321499 0.94477318 0.88560158 0.96245059]
# Confusion Matrix for F (max_features) of 1
# [[1194   93]
#  [ 114 1133]]
# tn: 1194, fp: 93, fn: 114, tp: 1133
# Accuracy of score of F of 1: 0.9254(+/- 0.0529)
# Youdens Index for F of 1: 0.8363
#
# Scores
# [0.92307692 0.95069034 0.94477318 0.94280079 0.94466403]
# Confusion Matrix for F (max_features) of 2
# [[1211   76]
#  [  87 1160]]
# tn: 1211, fp: 76, fn: 87, tp: 1160
# Accuracy of score of F of 2: 0.9412(+/- 0.0189)
# Youdens Index for F of 2: 0.8712
#
# Scores
# [0.95857988 0.96449704 0.9408284  0.95266272 0.9486166 ]
# Confusion Matrix for F (max_features) of 3
# [[1232   55]
#  [  64 1183]]
# tn: 1232, fp: 55, fn: 64, tp: 1183
# Accuracy of score of F of 3: 0.9530(+/- 0.0163)
# Youdens Index for F of 3: 0.9059
#
# Scores
# [0.95857988 0.97435897 0.94674556 0.94674556 0.9229249 ]
# Confusion Matrix for F (max_features) of 4
# [[1231   56]
#  [  57 1190]]
# tn: 1231, fp: 56, fn: 57, tp: 1190
# Accuracy of score of F of 4: 0.9499(+/- 0.0337)
# Youdens Index for F of 4: 0.9108
#
# Scores
# [0.96646943 0.94280079 0.96449704 0.97238659 0.95652174]
# Confusion Matrix for F (max_features) of 5
# [[1243   44]
#  [  49 1198]]
# tn: 1243, fp: 44, fn: 49, tp: 1198
# Accuracy of score of F of 5: 0.9605(+/- 0.0204)
# Youdens Index for F of 5: 0.9265
#
# Scores
# [0.96646943 0.97633136 0.96055227 0.93293886 0.96837945]
# Confusion Matrix for F (max_features) of 6
# [[1241   46]
#  [  50 1197]]
# tn: 1241, fp: 46, fn: 50, tp: 1197
# Accuracy of score of F of 6: 0.9609(+/- 0.0298)
# Youdens Index for F of 6: 0.9242
#
# Scores
# [0.96252465 0.96844181 0.96646943 0.95463511 0.94466403]
# Confusion Matrix for F (max_features) of 7
# [[1232   55]
#  [  48 1199]]
# tn: 1232, fp: 55, fn: 48, tp: 1199
# Accuracy of score of F of 7: 0.9593(+/- 0.0175)
# Youdens Index for F of 7: 0.9188
#
# Scores
# [0.96055227 0.96449704 0.96252465 0.94674556 0.97233202]
# Confusion Matrix for F (max_features) of 8
# [[1237   50]
#  [  59 1188]]
# tn: 1237, fp: 50, fn: 59, tp: 1188
# Accuracy of score of F of 8: 0.9613(+/- 0.0166)
# Youdens Index for F of 8: 0.9138
#
# Scores
# [0.96449704 0.96449704 0.95857988 0.9566075  0.97233202]
# Confusion Matrix for F (max_features) of 9
# [[1242   45]
#  [  45 1202]]
# tn: 1242, fp: 45, fn: 45, tp: 1202
# Accuracy of score of F of 9: 0.9633(+/- 0.0110)
# Youdens Index for F of 9: 0.9289
#
# Scores
# [0.95857988 0.97238659 0.96055227 0.95463511 0.97035573]
# Confusion Matrix for F (max_features) of 10
# [[1240   47]
#  [  40 1207]]
# tn: 1240, fp: 47, fn: 40, tp: 1207
# Accuracy of score of F of 10: 0.9633(+/- 0.0138)
# Youdens Index for F of 10: 0.9314
#
# Scores
# [0.96449704 0.97633136 0.97633136 0.95266272 0.96837945]
# Confusion Matrix for F (max_features) of 11
# [[1232   55]
#  [  41 1206]]
# tn: 1232, fp: 55, fn: 41, tp: 1206
# Accuracy of score of F of 11: 0.9676(+/- 0.0176)
# Youdens Index for F of 11: 0.9244
#
# Scores
# [0.9566075  0.9704142  0.96844181 0.95266272 0.9743083 ]
# Confusion Matrix for F (max_features) of 12
# [[1238   49]
#  [  39 1208]]
# tn: 1238, fp: 49, fn: 39, tp: 1208
# Accuracy of score of F of 12: 0.9645(+/- 0.0167)
# Youdens Index for F of 12: 0.9307
#
# Scores
# [0.95857988 0.97238659 0.96844181 0.94674556 0.96837945]
# Confusion Matrix for F (max_features) of 13
# [[1247   40]
#  [  40 1207]]
# tn: 1247, fp: 40, fn: 40, tp: 1207
# Accuracy of score of F of 13: 0.9629(+/- 0.0186)
# Youdens Index for F of 13: 0.9368
#
# Scores
# [0.96252465 0.97633136 0.94871795 0.95266272 0.97628458]
# Confusion Matrix for F (max_features) of 14
# [[1238   49]
#  [  44 1203]]
# tn: 1238, fp: 49, fn: 44, tp: 1203
# Accuracy of score of F of 14: 0.9633(+/- 0.0231)
# Youdens Index for F of 14: 0.9266
#
# Scores
# [0.95857988 0.97238659 0.95069034 0.95463511 0.97233202]
# Confusion Matrix for F (max_features) of 15
# [[1244   43]
#  [  46 1201]]
# tn: 1244, fp: 43, fn: 46, tp: 1201
# Accuracy of score of F of 15: 0.9617(+/- 0.0181)
# Youdens Index for F of 15: 0.9297
#
# Scores
# [0.94674556 0.96646943 0.96844181 0.95266272 0.96442688]
# Confusion Matrix for F (max_features) of 16
# [[1238   49]
#  [  40 1207]]
# tn: 1238, fp: 49, fn: 40, tp: 1207
# Accuracy of score of F of 16: 0.9597(+/- 0.0170)
# Youdens Index for F of 16: 0.9298
#
# Scores
# [0.95857988 0.9704142  0.96449704 0.96055227 0.96245059]
# Confusion Matrix for F (max_features) of 17
# [[1237   50]
#  [  44 1203]]
# tn: 1237, fp: 50, fn: 44, tp: 1203
# Accuracy of score of F of 17: 0.9633(+/- 0.0081)
# Youdens Index for F of 17: 0.9259
#
# Scores
# [0.95069034 0.96449704 0.96449704 0.95069034 0.9743083 ]
# Confusion Matrix for F (max_features) of 18
# [[1242   45]
#  [  48 1199]]
# tn: 1242, fp: 45, fn: 48, tp: 1199
# Accuracy of score of F of 18: 0.9609(+/- 0.0182)
# Youdens Index for F of 18: 0.9265
#
# Scores
# [0.94871795 0.97435897 0.96844181 0.95857988 0.96442688]
# Confusion Matrix for F (max_features) of 19
# [[1236   51]
#  [  43 1204]]
# tn: 1236, fp: 51, fn: 43, tp: 1204
# Accuracy of score of F of 19: 0.9629(+/- 0.0175)
# Youdens Index for F of 19: 0.9259
#
# The optimal F value is 13 with a Youden Index of 0.9368

# %%
# Import metrics module from scikit-learn
from sklearn import metrics

DTC = DecisionTreeClassifier(max_features=2)

# Train the model using the training sets
DTC.fit(x_train,y_train)

y_pred=DTC.predict(x_test)

# Get values for true positive (true male), true negative (true female),
# false positive (false male) and false negative (false female)
tp = sum((y_test == y_pred) * (y_test == 1) * 1)
print("TP: ", tp)
tn = sum((y_test == y_pred) * (y_test == 0) * 1)
print("TN: ", tn)
fp = sum((y_test != y_pred) * (y_test == 0) * 1)
print("FP: ", fp)
fn = sum((y_test != y_pred) * (y_test == 1) * 1)
print("FN: ", fn)

# Import division to ensure that division returns a float

# Define the sensitivity and specificity
sens = tp / (tp + fn)
spec = tn / (fp + tn)

print("Sensitivity is {}".format(sens))
print("Specificity is {}".format(spec))

# Calculate the Youden Index
youden = sens - (1 - spec)

print("Youden Index is {}".format(youden))
# Out:
# TP:  311
# TN:  285
# FP:  12
# FN:  26
# Sensitivity is 0.9228486646884273
# Specificity is 0.9595959595959596
# Youden Index is 0.8824446242843869
# C:\Users\thom37q2\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py:178: UserWarning: evaluating in Python space because the '*' operator is not supported by numexpr for the bool dtype, use '&' instead
#   f"evaluating in Python space because the {repr(op_str)} "

# %%
# Set dataset for confusion matrix using the test and prediction data
confusion_data = [[tn, fp, tn+fp], [fn, tp, fn+tp], [tn+fn, fp+tp, tn+fp+fn+tp]]

pd.options.display.float_format = '{:.4f}'.format

# Define the Pandas dataframe
df = pd.DataFrame(confusion_data, ['Actual Female', 'Actual Male', 'Total'], ['Predicted Female', 'Predicted Male', 'Total'])
sn.set(font_scale=1.4)
sn.heatmap(df, annot=True, fmt='g')

plt.title('DecisionTreeClassifier Confusion Matrix', loc='center')
plt.show()

# %%
import pydotplus

from sklearn.tree import export_graphviz
dot_data = export_graphviz(DTC,out_file="tree.dot",filled=True)

# %%
import graphviz


# %matplotlib inline
with open("tree.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
