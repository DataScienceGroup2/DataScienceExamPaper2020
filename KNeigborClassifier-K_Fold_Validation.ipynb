# %%
# Import numpy and pandas
import numpy as np
import pandas as pd

# Import operating specific functionality
import os

# Import Seaborn for visualisation
import seaborn as sn
# Import matplotlib for visualisation
import matplotlib.pyplot as plt

# Import timer
from timeit import default_timer as timer

# %%
# Create variable "data" containing the data from the voice.csv file
data = pd.read_csv("voice.csv")

# %%
# Show the head of the data, confirming that the data is read and that we have all columns
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000   male
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632   male
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512   male
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119   male
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %%
# Convert the label from text male/female to binary value of 1 or 0
data.label = [1 if each == "male" else 0 for each in  data.label]
# Show head of data to confirm that label value is changed
data.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR       skew  \
# 0  0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462
# 1  0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2  0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3  0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4  0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
#
#           kurt    sp.ent       sfm  ...  centroid   meanfun    minfun  \
# 0   274.402906  0.893369  0.491918  ...  0.059781  0.084279  0.015702
# 1   634.613855  0.892193  0.513724  ...  0.066009  0.107937  0.015826
# 2  1024.927705  0.846389  0.478905  ...  0.077316  0.098706  0.015656
# 3     4.177296  0.963322  0.727232  ...  0.151228  0.088965  0.017798
# 4     4.333713  0.971955  0.783568  ...  0.135120  0.106398  0.016931
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx  label
# 0  0.275862  0.007812  0.007812  0.007812  0.000000  0.000000      1
# 1  0.250000  0.009014  0.007812  0.054688  0.046875  0.052632      1
# 2  0.271186  0.007990  0.007812  0.015625  0.007812  0.046512      1
# 3  0.250000  0.201497  0.007812  0.562500  0.554688  0.247119      1
# 4  0.266667  0.712812  0.007812  5.484375  5.476562  0.208274      1
#
# [5 rows x 21 columns]

# %%
# Set variable "gender" to be the label column
gender = data.label
# Drop the label column from the data so that we now have features and labels separated
data.drop(["label"], axis = 1, inplace = True)

# %%
#Normalize the data to ensure that differing magnitude within features does not create a problem when running the model
data = (data-np.min(data))/(np.max(data)-np.min(data))

# Set variable "features" to be the normalized data
features = data

features.head()
# Out:
#    meanfreq        sd    median       Q25       Q75       IQR      skew  \
# 0  0.096419  0.473409  0.084125  0.060063  0.204956  0.254828  0.367853
# 1  0.125828  0.505075  0.116900  0.077635  0.215683  0.246961  0.644279
# 2  0.179222  0.675536  0.102873  0.034284  0.385912  0.457148  0.885255
# 3  0.528261  0.554611  0.587559  0.389906  0.715802  0.407358  0.031549
# 4  0.452195  0.627209  0.454272  0.317627  0.707515  0.474474  0.027742
#
#        kurt    sp.ent       sfm      mode  centroid   meanfun    minfun  \
# 0  0.208279  0.635798  0.564526  0.000000  0.096419  0.157706  0.030501
# 1  0.483766  0.630964  0.591578  0.000000  0.125828  0.287642  0.031140
# 2  0.782275  0.442738  0.548382  0.000000  0.179222  0.236945  0.030264
# 3  0.001613  0.923261  0.856457  0.299565  0.528261  0.183442  0.041287
# 4  0.001732  0.958736  0.926348  0.372362  0.452195  0.279190  0.036829
#
#      maxfun   meandom    mindom    maxdom   dfrange   modindx
# 0  0.981526  0.000000  0.006452  0.000000  0.000000  0.000000
# 1  0.834600  0.000407  0.006452  0.002144  0.002146  0.056449
# 2  0.954963  0.000060  0.006452  0.000357  0.000358  0.049885
# 3  0.834600  0.065659  0.006452  0.025375  0.025393  0.265043
# 4  0.929285  0.238994  0.006452  0.250536  0.250715  0.223380

# %%
# Import train_test_split function from scikit-learn
from sklearn.model_selection import train_test_split

# Split data into training set and testing set with a test size of 20% of the samples.
# The integer 42 is used for shuffling the data
x_train, x_test, y_train, y_test = train_test_split(features, gender, test_size = 0.2, random_state=42, stratify=gender)

# %%
# Import cross validation
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score
# Import KNN
from sklearn.neighbors import KNeighborsClassifier
# Import confusion matrix
from sklearn.metrics import confusion_matrix

K_Optimal = 0
best_youden = 0
youden_scores = []
cv_scores = []

for K in range(1, 16):

    # Create a KNN model
    knn = KNeighborsClassifier(n_neighbors = K)
    
    # Train the  model with a cross validation value of 5
    y_train_pred = cross_val_predict(knn, x_train, y_train, cv = 5)
    
    # Get the score for the cross validation value of 5
    kfold_score_start = timer()
    scores = cross_val_score(knn, x_train, y_train, cv = 5)
    print("K-fold score mean: {}".format(scores.mean()))
    kfold_score_end = timer()
    # Get the time for cross validation
    kfold_score_time = (kfold_score_end - kfold_score_start)
    
    print("Cross validation scores for K of {}: {}".format(K, scores))
    
    # Print a simple confusion matrix for this cross validation
    print("Confusion Matrix for K of {}".format(K))
    print(confusion_matrix(y_train, y_train_pred))
    
    # Get the values for True Negatives,False Positives, Falses Negatives and True Positives
    tn, fp, fn, tp = confusion_matrix(y_train, y_train_pred).ravel()
    # Print the 4 values from above
    print("tn: {}, fp: {}, fn: {}, tp: {}".format(tn, fp, fn, tp))
    
    # Calculate sensitivity and Specificity
    sens = tp / (tp + fn)
    spec = tn / (fp + tn)
    
    # Calculate the Youdens Index and add it to the array of all youden indeces
    youden = sens - (1 - spec)
    youden_scores.append(youden)
    
    # Add the score for this cross validation to the array of scores
    cv_scores.append(scores)
    
    print("Accuracy of score of K of {}: {:.4f}(+/- {:.4f})".format(K, scores.mean(), scores.std() * 2))
    print("Youdens Index for K of {}: {:.4f}\n ".format(K, youden))
    
    # Check if the Youdens Index is the best and if so set this value and the optimal K value
    if best_youden < youden:
        best_youden = youden
        K_Optimal = K
        

# Print the optimal K value and it's accuracy
print("The optimal K value is {} with a Youden Index of {:.4f}".format(K_Optimal, best_youden))
# Out:
# K-fold score mean: 0.9731646280141263
# Cross validation scores for K of 1: [0.97435897 0.96449704 0.98027613 0.97435897 0.97233202]
# Confusion Matrix for K of 1
# [[1227   40]
#  [  28 1239]]
# tn: 1227, fp: 40, fn: 28, tp: 1239
# Accuracy of score of K of 1: 0.9732(+/- 0.0102)
# Youdens Index for K of 1: 0.9463
#
# K-fold score mean: 0.9711906822274715
# Cross validation scores for K of 2: [0.96844181 0.96844181 0.97633136 0.97435897 0.96837945]
# Confusion Matrix for K of 2
# [[1247   20]
#  [  53 1214]]
# tn: 1247, fp: 20, fn: 53, tp: 1214
# Accuracy of score of K of 2: 0.9712(+/- 0.0069)
# Youdens Index for K of 2: 0.9424
#
# K-fold score mean: 0.9719811960614635
# Cross validation scores for K of 3: [0.96252465 0.97238659 0.97633136 0.97633136 0.97233202]
# Confusion Matrix for K of 3
# [[1220   47]
#  [  24 1243]]
# tn: 1220, fp: 47, fn: 24, tp: 1243
# Accuracy of score of K of 3: 0.9720(+/- 0.0101)
# Youdens Index for K of 3: 0.9440
#
# K-fold score mean: 0.9739535826492348
# Cross validation scores for K of 4: [0.96449704 0.97435897 0.98224852 0.97633136 0.97233202]
# Confusion Matrix for K of 4
# [[1238   29]
#  [  37 1230]]
# tn: 1238, fp: 29, fn: 37, tp: 1230
# Accuracy of score of K of 4: 0.9740(+/- 0.0115)
# Youdens Index for K of 4: 0.9479
#
# K-fold score mean: 0.9692190752391422
# Cross validation scores for K of 5: [0.96252465 0.96844181 0.98027613 0.96449704 0.97035573]
# Confusion Matrix for K of 5
# [[1216   51]
#  [  27 1240]]
# tn: 1216, fp: 51, fn: 27, tp: 1240
# Accuracy of score of K of 5: 0.9692(+/- 0.0124)
# Youdens Index for K of 5: 0.9384
#
# K-fold score mean: 0.9735598849311223
# Cross validation scores for K of 6: [0.96844181 0.97435897 0.98224852 0.96844181 0.9743083 ]
# Confusion Matrix for K of 6
# [[1231   36]
#  [  31 1236]]
# tn: 1231, fp: 36, fn: 31, tp: 1236
# Accuracy of score of K of 6: 0.9736(+/- 0.0102)
# Youdens Index for K of 6: 0.9471
#
# K-fold score mean: 0.971193021025797
# Cross validation scores for K of 7: [0.96646943 0.96844181 0.98224852 0.96449704 0.9743083 ]
# Confusion Matrix for K of 7
# [[1221   46]
#  [  27 1240]]
# tn: 1221, fp: 46, fn: 27, tp: 1240
# Accuracy of score of K of 7: 0.9712(+/- 0.0129)
# Youdens Index for K of 7: 0.9424
#
# K-fold score mean: 0.971193021025797
# Cross validation scores for K of 8: [0.96646943 0.96844181 0.98027613 0.96646943 0.9743083 ]
# Confusion Matrix for K of 8
# [[1227   40]
#  [  33 1234]]
# tn: 1227, fp: 40, fn: 33, tp: 1234
# Accuracy of score of K of 8: 0.9712(+/- 0.0107)
# Youdens Index for K of 8: 0.9424
#
# K-fold score mean: 0.9688269367199134
# Cross validation scores for K of 9: [0.96252465 0.96252465 0.97830375 0.96449704 0.97628458]
# Confusion Matrix for K of 9
# [[1216   51]
#  [  28 1239]]
# tn: 1216, fp: 51, fn: 28, tp: 1239
# Accuracy of score of K of 9: 0.9688(+/- 0.0140)
# Youdens Index for K of 9: 0.9376
#
# K-fold score mean: 0.9704056255895722
# Cross validation scores for K of 10: [0.96449704 0.96449704 0.98224852 0.96252465 0.97826087]
# Confusion Matrix for K of 10
# [[1224   43]
#  [  32 1235]]
# tn: 1224, fp: 43, fn: 32, tp: 1235
# Accuracy of score of K of 10: 0.9704(+/- 0.0163)
# Youdens Index for K of 10: 0.9408
#
# K-fold score mean: 0.96725058664858
# Cross validation scores for K of 11: [0.9566075  0.9566075  0.97830375 0.96449704 0.98023715]
# Confusion Matrix for K of 11
# [[1213   54]
#  [  29 1238]]
# tn: 1213, fp: 54, fn: 29, tp: 1238
# Accuracy of score of K of 11: 0.9673(+/- 0.0205)
# Youdens Index for K of 11: 0.9345
#
# K-fold score mean: 0.9692229732363511
# Cross validation scores for K of 12: [0.96055227 0.96055227 0.97830375 0.96646943 0.98023715]
# Confusion Matrix for K of 12
# [[1220   47]
#  [  31 1236]]
# tn: 1220, fp: 47, fn: 31, tp: 1236
# Accuracy of score of K of 12: 0.9692(+/- 0.0170)
# Youdens Index for K of 12: 0.9384
#
# K-fold score mean: 0.9664608524140297
# Cross validation scores for K of 13: [0.9566075  0.95266272 0.98027613 0.96449704 0.97826087]
# Confusion Matrix for K of 13
# [[1210   57]
#  [  28 1239]]
# tn: 1210, fp: 57, fn: 28, tp: 1239
# Accuracy of score of K of 13: 0.9665(+/- 0.0223)
# Youdens Index for K of 13: 0.9329
#
# K-fold score mean: 0.9660655954970336
# Cross validation scores for K of 14: [0.96252465 0.95463511 0.97238659 0.96449704 0.97628458]
# Confusion Matrix for K of 14
# [[1215   52]
#  [  34 1233]]
# tn: 1215, fp: 52, fn: 34, tp: 1233
# Accuracy of score of K of 14: 0.9661(+/- 0.0152)
# Youdens Index for K of 14: 0.9321
#
# K-fold score mean: 0.9629082177577161
# Cross validation scores for K of 15: [0.95857988 0.94871795 0.97238659 0.96252465 0.97233202]
# Confusion Matrix for K of 15
# [[1204   63]
#  [  31 1236]]
# tn: 1204, fp: 63, fn: 31, tp: 1236
# Accuracy of score of K of 15: 0.9629(+/- 0.0179)
# Youdens Index for K of 15: 0.9258
#
# The optimal K value is 4 with a Youden Index of 0.9479

# %%
# Now set K to K_Optimal neighbours
K = K_Optimal
# Set variable "knn" to be the KNeighborsClassifier using K of K_Optimal from above
knn_fin = KNeighborsClassifier(n_neighbors = K)

# Train the model using the training sets
knn_fin.fit(x_train, y_train)

# Predict the response for the test dataset
y_pred = knn_fin.predict(x_test)

# Import metrics module from scikit-learn
from sklearn import metrics
# Check how often the knn model is correct
accuracy = metrics.accuracy_score(y_test, y_pred)
# Print the result
print("Accuracy of model was: ", accuracy)

# Get values for true positive (true male), true negative (true female),
# false positive (false male) and false negative (false female)
tp = sum((y_test == y_pred) & (y_test == 1) * 1)
print("TP: ", tp)
tn = sum((y_test == y_pred) & (y_test == 0) * 1)
print("TN: ", tn)
fp = sum((y_test != y_pred) & (y_test == 0) * 1)
print("FP: ", fp)
fn = sum((y_test != y_pred) & (y_test == 1) * 1)
print("FN: ", fn)

# Define the sensitivity and specificity
sens = tp / (tp + fn)
spec = tn / (fp + tn)

print("Sensitivity is {}".format(sens))
print("Specificity is {}".format(spec))

# Calculate the Youden Index
youden = sens - (1 - spec)

print("Youden Index is {}".format(youden))
# Out:
# Accuracy of model was:  0.9858044164037855
# TP:  313
# TN:  312
# FP:  5
# FN:  4
# Sensitivity is 0.9873817034700315
# Specificity is 0.9842271293375394
# Youden Index is 0.9716088328075709

# %%
# Set dataset for confusion matrix using the test and prediction data
confusion_data = [[tn, fp, tn+fp], [fn, tp, fn+tp], [tn+fn, fp+tp, tn+fp+fn+tp]]

pd.options.display.float_format = '{:.4f}'.format

# Define the Pandas dataframe
df = pd.DataFrame(confusion_data, ['Actual Female', 'Actual Male', 'Total'], ['Predicted Female', 'Predicted Male', 'Total'])
sn.set(font_scale=1.4)
sn.heatmap(df, annot=True, fmt='g')

plt.title('KNeighborsClassifier Confusion Matrix', loc='center')
plt.show()

# %%
# Generate a plot with the K values and their corresponding Youden Indexes
plt.plot(range(1,16), youden_scores)
plt.xlabel("K Values")
plt.ylabel("Youden Index")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
